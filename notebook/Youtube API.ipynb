# %%
#https://developers.google.com/youtube/articles/view_youtube_jsonc_responses
#https://developers.google.com/youtube/2.0/developers_guide_jsonc

import requests
import json
import time

f= open('tedx_sample.txt','w')

user_id = "tedxtalks"
page = 1
maxcount = 25
count = 0
start_index = 0

# Obtaining Total page number
s = requests.get("https://gdata.youtube.com/feeds/api/users/"+user_id+"/uploads?v=2&alt=jsonc&start-index=1&max-result=1")
data = [json.loads(row) for row in s.content.split("\n") if row]
totalcount = data[0]['data']['totalItems']
pagenumber = totalcount/maxcount +1

key = ['id', 'uploaded', 'category', 'title', 'tags', 'thumbnail', 'duration', 'likeCount', 'rating', 'ratingCount', 'viewCount', 'favoriteCount', 'commentCount'] 
tedx ={'id':'',
        'data':{
                   'uploaded':'',
                   'title':'',
                   'tags':'',
                   'thumbnail':'',
                   'duration':'',
                   'likeCount':'',
                   'rating':'',
                   'ratingCount':'',
                   'viewCount':'',
                   'favoriteCount':'',
                   'commentCount':''
       }
}

# Obtaining Data from each page (sample)
for index in range(1,2): #range(1,pagenumber):
    # changing index number 
    if index == 1:
        start_index = 1
    else:
        start_index = index*maxcount
    
    s = requests.get("https://gdata.youtube.com/feeds/api/users/"+user_id+"/uploads?v=2&alt=jsonc&start-index="+str(start_index)+"&max-result="+str(maxcount))
    data = [json.loads(row) for row in s.content.split("\n") if row]
    metadata = data[0]['data']['items']
    
    # obtaining each data in a page (25 items)
    for i in range(len(metadata)):
        count +=1
        u = metadata[i]

        #missing key-value pair
        for j in key:
            if j=='id':
                tedx['id']=u['id']
            elif j =='thumbnail':
                tedx['data'][j] = u[j][u'hqDefault']
            elif j == 'title': 
                tedx['data'][j] = u[j].encode('utf-8')
            else:
                tedx['data'][j] = u[j] if not j in list(set(key) -set(u.keys())) else '-'
        
        the_dump = json.dumps(tedx)
        print the_dump
#        print count, tedx['id']    
#    print 'completed '+str(count)

    # delay
    time.sleep(1)

# https://developers.google.com/youtube/2.0/developers_guide_jsonc
# Out:
# {"data": {"uploaded": "2013-04-28T01:37:40.000Z", "rating": 5.0, "tags": "-", "likeCount": "2", "commentCount": 0, "ratingCount": 2, "duration": 583, "category": "Nonprofit", "viewCount": 23, "title": "Building Bridges of Peace: Edward Daleng at TEDxViadellaConciliazione", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/_QIBwsuaPBs/hqdefault.jpg"}, "id": "_QIBwsuaPBs"}
# {"data": {"uploaded": "2013-04-27T23:56:51.000Z", "rating": 5.0, "tags": "-", "likeCount": "7", "commentCount": 0, "ratingCount": 7, "duration": 822, "category": "Nonprofit", "viewCount": 79, "title": "Matters of Our Universe: Abishek Kumar at TEDxStanleyPark", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/ew0ovccWuQg/hqdefault.jpg"}, "id": "ew0ovccWuQg"}
# {"data": {"uploaded": "2013-04-27T22:55:18.000Z", "rating": "-", "tags": "-", "likeCount": "-", "commentCount": 0, "ratingCount": "-", "duration": 759, "category": "Nonprofit", "viewCount": 15, "title": "Darren Dougall at TEDxQueensU 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/sOjYbAKJmKg/hqdefault.jpg"}, "id": "sOjYbAKJmKg"}
# {"data": {"uploaded": "2013-04-27T15:40:54.000Z", "rating": 5.0, "tags": "-", "likeCount": "1", "commentCount": 0, "ratingCount": 1, "duration": 1154, "category": "Nonprofit", "viewCount": 19, "title": "[Title of Your Video]: Heather Jarvis and Sonya JF Barnett at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/gifXXSGtPl8/hqdefault.jpg"}, "id": "gifXXSGtPl8"}
# {"data": {"uploaded": "2013-04-27T15:32:43.000Z", "rating": "-", "tags": "-", "likeCount": "-", "commentCount": 0, "ratingCount": "-", "duration": 485, "category": "Nonprofit", "viewCount": 13, "title": "Live Performance: krNfx and Elysha Poirier at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/fEqpJxIpBgc/hqdefault.jpg"}, "id": "fEqpJxIpBgc"}
# {"data": {"uploaded": "2013-04-27T15:31:34.000Z", "rating": 5.0, "tags": "-", "likeCount": "2", "commentCount": 0, "ratingCount": 2, "duration": 995, "category": "Nonprofit", "viewCount": 15, "title": "[Title of Your Video]: Laura Reinsborough at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/gt8F50o0TK4/hqdefault.jpg"}, "id": "gt8F50o0TK4"}
# {"data": {"uploaded": "2013-04-27T15:24:53.000Z", "rating": 5.0, "tags": "-", "likeCount": "1", "commentCount": 1, "ratingCount": 1, "duration": 437, "category": "Nonprofit", "viewCount": 24, "title": "[Title of Your Video]: Angie Draskovic at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/QnBXP-Uw2YI/hqdefault.jpg"}, "id": "QnBXP-Uw2YI"}
# {"data": {"uploaded": "2013-04-27T15:24:01.000Z", "rating": 5.0, "tags": "-", "likeCount": "1", "commentCount": 1, "ratingCount": 1, "duration": 596, "category": "Nonprofit", "viewCount": 14, "title": "[Title of Your Video]: Susur Lee at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/Se8Vs1zeV2Q/hqdefault.jpg"}, "id": "Se8Vs1zeV2Q"}
# {"data": {"uploaded": "2013-04-27T15:23:47.000Z", "rating": "-", "tags": "-", "likeCount": "-", "commentCount": 0, "ratingCount": "-", "duration": 1116, "category": "Nonprofit", "viewCount": 15, "title": "[Title of Your Video]: Jon Dwyer at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/yyT1_QBj0WU/hqdefault.jpg"}, "id": "yyT1_QBj0WU"}
# {"data": {"uploaded": "2013-04-27T15:20:13.000Z", "rating": 5.0, "tags": "-", "likeCount": "1", "commentCount": 0, "ratingCount": 1, "duration": 354, "category": "Nonprofit", "viewCount": 6, "title": "Live Performance: Lemon Bucket Orkestra at TEDxToronto 2012", "favoriteCount": 0, "thumbnail": "http://i.ytimg.com/vi/l5DxYFB5u5g/hqdefault.jpg"}, "id": "l5DxYFB5u5g"}
