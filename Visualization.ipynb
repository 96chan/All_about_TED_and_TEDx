# %% [markdown]
# # Language Data by Year

# %%
# TEDx data by language

# %%
import json

TEDX_JSON_FILE = "final_tedx.json"
tedx_lang = {}
event_array = []

with open(TEDX_JSON_FILE, "r") as tedx_json_file:
    for i, line in enumerate(tedx_json_file):
        u = json.loads(line)        
        year = u['data']['uploaded'][:4]
        # extract language attribute from corpus
        if u['data'].has_key('lang') and u['data']['viewCount'] != '-':
            # language name
            lang = u['data']['lang']
            # event name
            if u['data'].has_key('event'):
                event = u['data']['event']
            elif u['data']['title'].find('at TEDx'):
                event = u['data']['title'][u['data']['title'].find('at TEDx')+3:]
            # view_cnt
            view_cnt = u['data']['viewCount']
                
            # check language in the dictionary 
            if lang in tedx_lang.keys():   # existed language
                # view count
                tedx_lang[lang][0] += int(view_cnt)
                # event append
                if event not in event_array:
                    event_array.append(event)
                    # event count
                    tedx_lang[lang][1] += 1
                # video count
                tedx_lang[lang][2] += 1
            else:                          # new langauge
                # event append
                if event not in event_array:
                    event_array.append(event)
                tedx_lang[lang] = [int(view_cnt),1,1] # view/event/video
    
print tedx_lang
# Out:
# {u'Swedish': [44697, 7, 39], u'Icelandic': [24456, 1, 28], u'Estonian': [60411, 3, 50], u'Turkish': [199883, 3, 75], u'Romanian': [191920, 8, 71], u'Azerbaijani': [9190, 2, 17], u'Hindi': [9156, 2, 10], u'Dutch': [20211, 4, 25], u'Korean': [886851, 74, 573], u'Indonesian': [471437, 9, 58], u'Hungarian': [91745, 8, 54], u'Ukrainian': [62395, 9, 40], u'Lithuanian': [24422, 1, 8], u'Malay': [670, 1, 1], u'French': [3531082, 66, 550], u'Catalan': [12520, 4, 57], u'Russian': [382446, 37, 347], u'Thai': [255, 1, 1], u'Italian': [340887, 22, 237], u'Tamil': [44816, 1, 7], u'Slovene': [131883, 5, 73], u'Finnish': [84745, 2, 28], u'Hebrew': [24835, 12, 13], u'Bulgarian': [178818, 4, 65], u'Greek': [487140, 2, 104], u'English': [57297339, 1583, 15684], u'Rajasthani': [93767, 2, 17], u'Croatian': [23147, 11, 44], u'Portuguese': [1486959, 104, 913], u'Chinese': [106780, 14, 63], u'Czech': [207996, 5, 64], u'Japanese': [898128, 13, 258], u'Galician': [13146, 1, 7], u'German': [160169, 18, 118], u'Slovak': [128627, 5, 59], u'Spanish': [4111914, 127, 1225], u'Urdu': [171188, 3, 26], u'Polish': [798470, 9, 134], u'Arabic': [4127472, 40, 396]}

# %%
# TEDx language data by year

# %%
import json

TEDX_JSON_FILE = "final_tedx.json"
tedx_year = {'2009':{}, '2010':{}, '2011':{}, '2012':{}, '2013':{}}
event_year = {'2009':[], '2010':[], '2011':[], '2012':[], '2013':[]}
year_array =['2009','2010','2011','2012','2013']

with open(TEDX_JSON_FILE, "r") as tedx_json_file:
    for i, line in enumerate(tedx_json_file):
        u = json.loads(line)        
        year = u['data']['uploaded'][:4]
        # extract language attribute from corpus
        if u['data'].has_key('lang') and u['data']['viewCount'] != '-':
            # language name
            lang = u['data']['lang']
            # event name
            if u['data'].has_key('event'):
                event = u['data']['event']
            elif u['data']['title'].find('at TEDx'):
                event = u['data']['title'][u['data']['title'].find('at TEDx')+3:]
            # view_cnt
            view_cnt = u['data']['viewCount']
            
            for i in year_array:
                if year == i:
                    # check language in the dictionary 
                    if lang in tedx_year[year].keys():   # existed language
                        # view count
                        tedx_year[year][lang][0] += int(view_cnt)
                        # event append
                        if event not in event_year[year]:
                            event_year[year].append(event)
                            # event count
                            tedx_year[year][lang][1] += 1
                        # video count
                        tedx_year[year][lang][2] += 1
                    else:                          # new langauge
                        # event append
                        if event not in event_year[year]:
                            event_year[year].append(event)
                        tedx_year[year][lang] = [int(view_cnt),1,1] # view/event/video
        
print tedx_year
# Out:
# {'2009': {u'Portuguese': [27104, 3, 9], u'Slovene': [10844, 1, 4], u'Ukrainian': [8584, 1, 3], u'German': [8106, 1, 1], u'Romanian': [23750, 1, 2], u'Spanish': [19157, 1, 3], u'Malay': [670, 1, 1], u'Greek': [1584, 1, 1], u'Icelandic': [16926, 1, 14], u'English': [1682910, 45, 290], u'Russian': [28304, 2, 7], u'Korean': [17723, 1, 11], u'Italian': [11077, 1, 7]}, '2011': {u'Swedish': [3186, 3, 5], u'Icelandic': [6498, 1, 10], u'Estonian': [18989, 1, 16], u'Turkish': [120479, 2, 17], u'Romanian': [115947, 2, 28], u'Azerbaijani': [5720, 1, 4], u'Hindi': [1924, 1, 2], u'Dutch': [5894, 2, 4], u'Korean': [203726, 40, 219], u'Indonesian': [193243, 5, 21], u'Hungarian': [75993, 1, 25], u'Ukrainian': [16817, 1, 9], u'French': [636424, 13, 115], u'Catalan': [944, 1, 4], u'Russian': [108993, 23, 115], u'Croatian': [1910, 8, 8], u'Tamil': [44816, 1, 7], u'Slovene': [11416, 3, 10], u'Finnish': [32053, 1, 17], u'Hebrew': [21367, 2, 3], u'Bulgarian': [89274, 2, 20], u'Greek': [114832, 1, 22], u'English': [23659350, 632, 4401], u'Rajasthani': [47946, 2, 10], u'Italian': [155295, 11, 68], u'Portuguese': [565467, 49, 231], u'Chinese': [24944, 2, 9], u'Czech': [158376, 1, 28], u'Japanese': [243656, 7, 77], u'German': [39830, 8, 36], u'Slovak': [54768, 3, 19], u'Spanish': [1561392, 41, 264], u'Urdu': [83483, 1, 6], u'Polish': [38791, 2, 27], u'Arabic': [1330391, 13, 139]}, '2010': {u'Swedish': [28931, 4, 23], u'Estonian': [25709, 1, 5], u'Romanian': [30335, 1, 9], u'Hindi': [2087, 1, 2], u'Korean': [553794, 25, 118], u'Indonesian': [187375, 2, 10], u'Hungarian': [1934, 2, 2], u'Ukrainian': [25743, 1, 9], u'Lithuanian': [24422, 1, 8], u'French': [1521047, 6, 56], u'Russian': [150776, 3, 25], u'Slovene': [68588, 1, 30], u'Finnish': [52692, 2, 11], u'Spanish': [1620656, 33, 210], u'Greek': [287836, 3, 43], u'English': [9969544, 442, 2572], u'Rajasthani': [45821, 1, 7], u'Italian': [61155, 2, 35], u'Portuguese': [401315, 8, 142], u'Czech': [30468, 1, 11], u'Japanese': [363966, 1, 47], u'Galician': [2070, 1, 2], u'German': [75350, 2, 11], u'Slovak': [44058, 1, 11], u'Hebrew': [3468, 10, 10], u'Urdu': [53691, 1, 3], u'Polish': [38571, 2, 25], u'Arabic': [572364, 3, 38]}, '2013': {u'Turkish': [12282, 1, 25], u'Romanian': [1376, 3, 4], u'Azerbaijani': [875, 1, 7], u'Hindi': [133, 1, 1], u'Dutch': [195, 1, 1], u'Korean': [11334, 7, 37], u'Indonesian': [1947, 2, 12], u'Hungarian': [10049, 3, 22], u'French': [268420, 19, 116], u'Catalan': [3040, 2, 18], u'Russian': [26514, 7, 55], u'Italian': [8456, 3, 32], u'Slovene': [19577, 1, 12], u'Bulgarian': [22224, 1, 11], u'Greek': [23884, 2, 13], u'English': [4097079, 304, 2118], u'Croatian': [2238, 2, 17], u'Portuguese': [134268, 20, 141], u'Chinese': [2731, 1, 9], u'Czech': [5873, 1, 9], u'Japanese': [21305, 7, 56], u'Galician': [1633, 1, 1], u'German': [9375, 4, 18], u'Spanish': [345293, 37, 316], u'Polish': [665644, 7, 49], u'Arabic': [1291220, 16, 77]}, '2012': {u'Swedish': [12580, 2, 11], u'Icelandic': [1032, 1, 4], u'Estonian': [15713, 3, 29], u'Turkish': [67122, 2, 33], u'Romanian': [20512, 5, 28], u'Azerbaijani': [2595, 1, 6], u'Hindi': [5012, 2, 5], u'Dutch': [14122, 4, 20], u'Korean': [100274, 28, 188], u'Bulgarian': [67320, 4, 34], u'Hungarian': [3769, 5, 5], u'Ukrainian': [11251, 8, 19], u'French': [1105191, 47, 263], u'Catalan': [8536, 4, 35], u'Russian': [67859, 17, 145], u'Thai': [255, 1, 1], u'Croatian': [18999, 1, 19], u'Slovene': [21458, 3, 17], u'Indonesian': [88872, 5, 15], u'Greek': [59004, 1, 25], u'English': [17888456, 711, 6303], u'Italian': [104904, 12, 95], u'Portuguese': [358805, 52, 390], u'Chinese': [79105, 11, 45], u'Czech': [13279, 3, 16], u'Japanese': [269201, 6, 78], u'Galician': [9443, 1, 4], u'German': [27508, 6, 52], u'Slovak': [29801, 3, 29], u'Spanish': [565416, 59, 432], u'Urdu': [34014, 2, 17], u'Polish': [55464, 2, 33], u'Arabic': [933497, 24, 142]}}

# %%
# confirmation
sum = 0
for i in year_array:
    if tedx_year[i].has_key('Arabic'):
        sum += tedx_year[i]['Arabic'][0]
sum == tedx_lang['Arabic'][0]
# Out:
# True

# %%
# Filling up missing values for keeping the same size of data each year
keys = []
tedx_test = tedx_year
tedx_test['2011']['Galician'] = [0,0,-1]
tedx_test['2011']['Malay'] = [0,0,-1]
tedx_test['2011']['Thai'] = [0,0,-1]
tedx_test['2011']['Lithuanian'] = [0,0,-1]

keys.append(tedx_test['2011'].keys())

for i in year_array:
    sub_keys = []
    # calculate missing language
    sub_keys.append((list(set(tedx_test['2011'].keys()) - set(tedx_test[i].keys()))))
    for j in sub_keys[0]:
        # filling up dummy variable (0,0,0)
        tedx_test[i][j] = [0,0,-1]

# %%
# Data Formating 

tedx= {'2009':[],'2010':[],'2011':[],'2012':[],'2013':[]}

for i in year_array:
    for j in tedx_test[i].keys():
        for lang in keys[0]:
            if j == lang:

                tedx[i].append({'language':str(j),'viewcount':tedx_test[i][j][0], 'eventcount':tedx_test[i][j][1], 'videocount':tedx_test[i][j][2]})

# %%
tedx
# Out:
# {'2009': [{'eventcount': 0,
#    'language': 'Swedish',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Icelandic',
#    'videocount': 14,
#    'viewcount': 16926},
#   {'eventcount': 0, 'language': 'Estonian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Turkish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Romanian',
#    'videocount': 2,
#    'viewcount': 23750},
#   {'eventcount': 0,
#    'language': 'Azerbaijani',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Hindi', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Dutch', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Korean',
#    'videocount': 11,
#    'viewcount': 17723},
#   {'eventcount': 0,
#    'language': 'Indonesian',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Hungarian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Ukrainian',
#    'videocount': 3,
#    'viewcount': 8584},
#   {'eventcount': 0,
#    'language': 'Lithuanian',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 1, 'language': 'Malay', 'videocount': 1, 'viewcount': 670},
#   {'eventcount': 0, 'language': 'French', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Catalan', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 2,
#    'language': 'Russian',
#    'videocount': 7,
#    'viewcount': 28304},
#   {'eventcount': 0, 'language': 'Thai', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Croatian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Tamil', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Slovene',
#    'videocount': 4,
#    'viewcount': 10844},
#   {'eventcount': 0, 'language': 'Finnish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Hebrew', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Bulgarian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1, 'language': 'Greek', 'videocount': 1, 'viewcount': 1584},
#   {'eventcount': 45,
#    'language': 'English',
#    'videocount': 290,
#    'viewcount': 1682910},
#   {'eventcount': 0,
#    'language': 'Rajasthani',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Italian',
#    'videocount': 7,
#    'viewcount': 11077},
#   {'eventcount': 3,
#    'language': 'Portuguese',
#    'videocount': 9,
#    'viewcount': 27104},
#   {'eventcount': 0, 'language': 'Chinese', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1, 'language': 'German', 'videocount': 1, 'viewcount': 8106},
#   {'eventcount': 0, 'language': 'Japanese', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Galician', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Czech', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Slovak', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Spanish',
#    'videocount': 3,
#    'viewcount': 19157},
#   {'eventcount': 0, 'language': 'Urdu', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Polish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Arabic', 'videocount': -1, 'viewcount': 0}],
#  '2010': [{'eventcount': 4,
#    'language': 'Swedish',
#    'videocount': 23,
#    'viewcount': 28931},
#   {'eventcount': 0, 'language': 'Icelandic', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Estonian',
#    'videocount': 5,
#    'viewcount': 25709},
#   {'eventcount': 0, 'language': 'Turkish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Romanian',
#    'videocount': 9,
#    'viewcount': 30335},
#   {'eventcount': 0,
#    'language': 'Azerbaijani',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 1, 'language': 'Hindi', 'videocount': 2, 'viewcount': 2087},
#   {'eventcount': 0, 'language': 'Dutch', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 25,
#    'language': 'Korean',
#    'videocount': 118,
#    'viewcount': 553794},
#   {'eventcount': 2,
#    'language': 'Indonesian',
#    'videocount': 10,
#    'viewcount': 187375},
#   {'eventcount': 2,
#    'language': 'Hungarian',
#    'videocount': 2,
#    'viewcount': 1934},
#   {'eventcount': 1,
#    'language': 'Ukrainian',
#    'videocount': 9,
#    'viewcount': 25743},
#   {'eventcount': 1,
#    'language': 'Lithuanian',
#    'videocount': 8,
#    'viewcount': 24422},
#   {'eventcount': 0, 'language': 'Malay', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 6,
#    'language': 'French',
#    'videocount': 56,
#    'viewcount': 1521047},
#   {'eventcount': 0, 'language': 'Catalan', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 3,
#    'language': 'Russian',
#    'videocount': 25,
#    'viewcount': 150776},
#   {'eventcount': 0, 'language': 'Thai', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Croatian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Tamil', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Slovene',
#    'videocount': 30,
#    'viewcount': 68588},
#   {'eventcount': 2,
#    'language': 'Finnish',
#    'videocount': 11,
#    'viewcount': 52692},
#   {'eventcount': 33,
#    'language': 'Spanish',
#    'videocount': 210,
#    'viewcount': 1620656},
#   {'eventcount': 0, 'language': 'Bulgarian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 3,
#    'language': 'Greek',
#    'videocount': 43,
#    'viewcount': 287836},
#   {'eventcount': 442,
#    'language': 'English',
#    'videocount': 2572,
#    'viewcount': 9969544},
#   {'eventcount': 1,
#    'language': 'Rajasthani',
#    'videocount': 7,
#    'viewcount': 45821},
#   {'eventcount': 2,
#    'language': 'Italian',
#    'videocount': 35,
#    'viewcount': 61155},
#   {'eventcount': 8,
#    'language': 'Portuguese',
#    'videocount': 142,
#    'viewcount': 401315},
#   {'eventcount': 0, 'language': 'Chinese', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1, 'language': 'Czech', 'videocount': 11, 'viewcount': 30468},
#   {'eventcount': 1,
#    'language': 'Japanese',
#    'videocount': 47,
#    'viewcount': 363966},
#   {'eventcount': 1,
#    'language': 'Galician',
#    'videocount': 2,
#    'viewcount': 2070},
#   {'eventcount': 2,
#    'language': 'German',
#    'videocount': 11,
#    'viewcount': 75350},
#   {'eventcount': 1,
#    'language': 'Slovak',
#    'videocount': 11,
#    'viewcount': 44058},
#   {'eventcount': 10,
#    'language': 'Hebrew',
#    'videocount': 10,
#    'viewcount': 3468},
#   {'eventcount': 1, 'language': 'Urdu', 'videocount': 3, 'viewcount': 53691},
#   {'eventcount': 2,
#    'language': 'Polish',
#    'videocount': 25,
#    'viewcount': 38571},
#   {'eventcount': 3,
#    'language': 'Arabic',
#    'videocount': 38,
#    'viewcount': 572364}],
#  '2011': [{'eventcount': 3,
#    'language': 'Swedish',
#    'videocount': 5,
#    'viewcount': 3186},
#   {'eventcount': 1,
#    'language': 'Icelandic',
#    'videocount': 10,
#    'viewcount': 6498},
#   {'eventcount': 1,
#    'language': 'Estonian',
#    'videocount': 16,
#    'viewcount': 18989},
#   {'eventcount': 2,
#    'language': 'Turkish',
#    'videocount': 17,
#    'viewcount': 120479},
#   {'eventcount': 2,
#    'language': 'Romanian',
#    'videocount': 28,
#    'viewcount': 115947},
#   {'eventcount': 1,
#    'language': 'Azerbaijani',
#    'videocount': 4,
#    'viewcount': 5720},
#   {'eventcount': 1, 'language': 'Hindi', 'videocount': 2, 'viewcount': 1924},
#   {'eventcount': 2, 'language': 'Dutch', 'videocount': 4, 'viewcount': 5894},
#   {'eventcount': 40,
#    'language': 'Korean',
#    'videocount': 219,
#    'viewcount': 203726},
#   {'eventcount': 5,
#    'language': 'Indonesian',
#    'videocount': 21,
#    'viewcount': 193243},
#   {'eventcount': 1,
#    'language': 'Hungarian',
#    'videocount': 25,
#    'viewcount': 75993},
#   {'eventcount': 1,
#    'language': 'Ukrainian',
#    'videocount': 9,
#    'viewcount': 16817},
#   {'eventcount': 0,
#    'language': 'Lithuanian',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Malay', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 13,
#    'language': 'French',
#    'videocount': 115,
#    'viewcount': 636424},
#   {'eventcount': 1, 'language': 'Catalan', 'videocount': 4, 'viewcount': 944},
#   {'eventcount': 23,
#    'language': 'Russian',
#    'videocount': 115,
#    'viewcount': 108993},
#   {'eventcount': 0, 'language': 'Thai', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 8,
#    'language': 'Croatian',
#    'videocount': 8,
#    'viewcount': 1910},
#   {'eventcount': 1, 'language': 'Tamil', 'videocount': 7, 'viewcount': 44816},
#   {'eventcount': 3,
#    'language': 'Slovene',
#    'videocount': 10,
#    'viewcount': 11416},
#   {'eventcount': 1,
#    'language': 'Finnish',
#    'videocount': 17,
#    'viewcount': 32053},
#   {'eventcount': 2, 'language': 'Hebrew', 'videocount': 3, 'viewcount': 21367},
#   {'eventcount': 2,
#    'language': 'Bulgarian',
#    'videocount': 20,
#    'viewcount': 89274},
#   {'eventcount': 1,
#    'language': 'Greek',
#    'videocount': 22,
#    'viewcount': 114832},
#   {'eventcount': 632,
#    'language': 'English',
#    'videocount': 4401,
#    'viewcount': 23659350},
#   {'eventcount': 2,
#    'language': 'Rajasthani',
#    'videocount': 10,
#    'viewcount': 47946},
#   {'eventcount': 11,
#    'language': 'Italian',
#    'videocount': 68,
#    'viewcount': 155295},
#   {'eventcount': 49,
#    'language': 'Portuguese',
#    'videocount': 231,
#    'viewcount': 565467},
#   {'eventcount': 2,
#    'language': 'Chinese',
#    'videocount': 9,
#    'viewcount': 24944},
#   {'eventcount': 1,
#    'language': 'Czech',
#    'videocount': 28,
#    'viewcount': 158376},
#   {'eventcount': 7,
#    'language': 'Japanese',
#    'videocount': 77,
#    'viewcount': 243656},
#   {'eventcount': 0, 'language': 'Galician', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 8,
#    'language': 'German',
#    'videocount': 36,
#    'viewcount': 39830},
#   {'eventcount': 3,
#    'language': 'Slovak',
#    'videocount': 19,
#    'viewcount': 54768},
#   {'eventcount': 41,
#    'language': 'Spanish',
#    'videocount': 264,
#    'viewcount': 1561392},
#   {'eventcount': 1, 'language': 'Urdu', 'videocount': 6, 'viewcount': 83483},
#   {'eventcount': 2,
#    'language': 'Polish',
#    'videocount': 27,
#    'viewcount': 38791},
#   {'eventcount': 13,
#    'language': 'Arabic',
#    'videocount': 139,
#    'viewcount': 1330391}],
#  '2012': [{'eventcount': 2,
#    'language': 'Swedish',
#    'videocount': 11,
#    'viewcount': 12580},
#   {'eventcount': 1,
#    'language': 'Icelandic',
#    'videocount': 4,
#    'viewcount': 1032},
#   {'eventcount': 3,
#    'language': 'Estonian',
#    'videocount': 29,
#    'viewcount': 15713},
#   {'eventcount': 2,
#    'language': 'Turkish',
#    'videocount': 33,
#    'viewcount': 67122},
#   {'eventcount': 5,
#    'language': 'Romanian',
#    'videocount': 28,
#    'viewcount': 20512},
#   {'eventcount': 1,
#    'language': 'Azerbaijani',
#    'videocount': 6,
#    'viewcount': 2595},
#   {'eventcount': 2, 'language': 'Hindi', 'videocount': 5, 'viewcount': 5012},
#   {'eventcount': 4, 'language': 'Dutch', 'videocount': 20, 'viewcount': 14122},
#   {'eventcount': 28,
#    'language': 'Korean',
#    'videocount': 188,
#    'viewcount': 100274},
#   {'eventcount': 4,
#    'language': 'Bulgarian',
#    'videocount': 34,
#    'viewcount': 67320},
#   {'eventcount': 5,
#    'language': 'Hungarian',
#    'videocount': 5,
#    'viewcount': 3769},
#   {'eventcount': 8,
#    'language': 'Ukrainian',
#    'videocount': 19,
#    'viewcount': 11251},
#   {'eventcount': 0,
#    'language': 'Lithuanian',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Malay', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 47,
#    'language': 'French',
#    'videocount': 263,
#    'viewcount': 1105191},
#   {'eventcount': 4,
#    'language': 'Catalan',
#    'videocount': 35,
#    'viewcount': 8536},
#   {'eventcount': 17,
#    'language': 'Russian',
#    'videocount': 145,
#    'viewcount': 67859},
#   {'eventcount': 1, 'language': 'Thai', 'videocount': 1, 'viewcount': 255},
#   {'eventcount': 1,
#    'language': 'Croatian',
#    'videocount': 19,
#    'viewcount': 18999},
#   {'eventcount': 0, 'language': 'Tamil', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 3,
#    'language': 'Slovene',
#    'videocount': 17,
#    'viewcount': 21458},
#   {'eventcount': 0, 'language': 'Finnish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Hebrew', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 5,
#    'language': 'Indonesian',
#    'videocount': 15,
#    'viewcount': 88872},
#   {'eventcount': 1, 'language': 'Greek', 'videocount': 25, 'viewcount': 59004},
#   {'eventcount': 711,
#    'language': 'English',
#    'videocount': 6303,
#    'viewcount': 17888456},
#   {'eventcount': 0,
#    'language': 'Rajasthani',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 12,
#    'language': 'Italian',
#    'videocount': 95,
#    'viewcount': 104904},
#   {'eventcount': 52,
#    'language': 'Portuguese',
#    'videocount': 390,
#    'viewcount': 358805},
#   {'eventcount': 11,
#    'language': 'Chinese',
#    'videocount': 45,
#    'viewcount': 79105},
#   {'eventcount': 3, 'language': 'Czech', 'videocount': 16, 'viewcount': 13279},
#   {'eventcount': 6,
#    'language': 'Japanese',
#    'videocount': 78,
#    'viewcount': 269201},
#   {'eventcount': 1,
#    'language': 'Galician',
#    'videocount': 4,
#    'viewcount': 9443},
#   {'eventcount': 6,
#    'language': 'German',
#    'videocount': 52,
#    'viewcount': 27508},
#   {'eventcount': 3,
#    'language': 'Slovak',
#    'videocount': 29,
#    'viewcount': 29801},
#   {'eventcount': 59,
#    'language': 'Spanish',
#    'videocount': 432,
#    'viewcount': 565416},
#   {'eventcount': 2, 'language': 'Urdu', 'videocount': 17, 'viewcount': 34014},
#   {'eventcount': 2,
#    'language': 'Polish',
#    'videocount': 33,
#    'viewcount': 55464},
#   {'eventcount': 24,
#    'language': 'Arabic',
#    'videocount': 142,
#    'viewcount': 933497}],
#  '2013': [{'eventcount': 0,
#    'language': 'Swedish',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Icelandic', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Estonian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Turkish',
#    'videocount': 25,
#    'viewcount': 12282},
#   {'eventcount': 3,
#    'language': 'Romanian',
#    'videocount': 4,
#    'viewcount': 1376},
#   {'eventcount': 1,
#    'language': 'Azerbaijani',
#    'videocount': 7,
#    'viewcount': 875},
#   {'eventcount': 1, 'language': 'Hindi', 'videocount': 1, 'viewcount': 133},
#   {'eventcount': 1, 'language': 'Dutch', 'videocount': 1, 'viewcount': 195},
#   {'eventcount': 7,
#    'language': 'Korean',
#    'videocount': 37,
#    'viewcount': 11334},
#   {'eventcount': 2,
#    'language': 'Indonesian',
#    'videocount': 12,
#    'viewcount': 1947},
#   {'eventcount': 3,
#    'language': 'Hungarian',
#    'videocount': 22,
#    'viewcount': 10049},
#   {'eventcount': 0, 'language': 'Ukrainian', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0,
#    'language': 'Lithuanian',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 0, 'language': 'Malay', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 19,
#    'language': 'French',
#    'videocount': 116,
#    'viewcount': 268420},
#   {'eventcount': 2,
#    'language': 'Catalan',
#    'videocount': 18,
#    'viewcount': 3040},
#   {'eventcount': 7,
#    'language': 'Russian',
#    'videocount': 55,
#    'viewcount': 26514},
#   {'eventcount': 0, 'language': 'Thai', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 3,
#    'language': 'Italian',
#    'videocount': 32,
#    'viewcount': 8456},
#   {'eventcount': 0, 'language': 'Tamil', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Slovene',
#    'videocount': 12,
#    'viewcount': 19577},
#   {'eventcount': 0, 'language': 'Finnish', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 0, 'language': 'Hebrew', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 1,
#    'language': 'Bulgarian',
#    'videocount': 11,
#    'viewcount': 22224},
#   {'eventcount': 2, 'language': 'Greek', 'videocount': 13, 'viewcount': 23884},
#   {'eventcount': 304,
#    'language': 'English',
#    'videocount': 2118,
#    'viewcount': 4097079},
#   {'eventcount': 0,
#    'language': 'Rajasthani',
#    'videocount': -1,
#    'viewcount': 0},
#   {'eventcount': 2,
#    'language': 'Croatian',
#    'videocount': 17,
#    'viewcount': 2238},
#   {'eventcount': 20,
#    'language': 'Portuguese',
#    'videocount': 141,
#    'viewcount': 134268},
#   {'eventcount': 1, 'language': 'Chinese', 'videocount': 9, 'viewcount': 2731},
#   {'eventcount': 1, 'language': 'Czech', 'videocount': 9, 'viewcount': 5873},
#   {'eventcount': 7,
#    'language': 'Japanese',
#    'videocount': 56,
#    'viewcount': 21305},
#   {'eventcount': 1,
#    'language': 'Galician',
#    'videocount': 1,
#    'viewcount': 1633},
#   {'eventcount': 4, 'language': 'German', 'videocount': 18, 'viewcount': 9375},
#   {'eventcount': 0, 'language': 'Slovak', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 37,
#    'language': 'Spanish',
#    'videocount': 316,
#    'viewcount': 345293},
#   {'eventcount': 0, 'language': 'Urdu', 'videocount': -1, 'viewcount': 0},
#   {'eventcount': 7,
#    'language': 'Polish',
#    'videocount': 49,
#    'viewcount': 665644},
#   {'eventcount': 16,
#    'language': 'Arabic',
#    'videocount': 77,
#    'viewcount': 1291220}]}

# %%
#visualization

# %%
from IPython.display import HTML
HTML('<iframe src="http://96chany.com/projects/tedx" width="1000" height="800"></iframe>')
# Out:
# <iframe src="http://96chany.com/projects/tedx" width="1000" height="800"></iframe>
